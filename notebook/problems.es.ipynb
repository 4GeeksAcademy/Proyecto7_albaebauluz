# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
from scipy import stats
import numpy as np
import statsmodels.api as sm

# Datos:
diet1=[2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
diet2=[3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

# Hipótesis:
# H0: No existe diferencia en la pérdida de peso medio entre las personas que siguieron la dieta 1 y la dieta 2 (Media dieta1 = Media dieta 2)
# H1: Existe diferencia en la pérdida de peso medio entre las personas que siguieron la dieta 1 y la dieta 2 (Media dieta1 != Media dieta 2)

p_valor = stats.ttest_ind(diet1, diet2).pvalue
nivel_alpha = 0.1

print(p_valor)   # P-valor= 0.004, por lo que se rechaza la HO.

if p_valor<nivel_alpha:
  print('Rechazamos la hipótesis nula. Por lo tanto, podemos afirmar que existe diferencia en la pérdida de peso medio entre las personas que siguieron la dieta 1 y la dieta 2.')
else:
  print('No se rechaza la hipótesis nula. Por lo que no podemos afirmar que existe diferencia en la pérdida de peso medio entre las personas que siguieron la dieta 1 y la dieta 2.')
# Out:
# 0.004083270191713912
# Rechazamos la hipótesis nula. Por lo tanto, podemos afirmar que existe diferencia en la pérdida de peso medio entre las personas que siguieron la dieta 1 y la dieta 2.

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Datos:
ferti1=[20, 21, 20, 19, 20]
ferti2=[22, 21, 23, 22, 21]
ferti3=[24, 23, 22, 23, 24]

# Hipótesis:
# H0: No existe diferencia en el rendimiento medio del maíz entre los tres tipos de fertilizantes  (Media ferti1 = Media ferti2 = Media ferti3)
# H1: Existe diferencia en el rendimiento medio del maíz entre los tres tipos de fertilizantes  (Media ferti1 != Media ferti2 = Media ferti3 | Media ferti1 = Media ferti2 != Media ferti3)

# Análisis
data = {
    'fertilizante': ['ferti1'] * 5 + ['ferti2'] * 5 + ['ferti3'] * 5,
    'rendimiento': ferti1 + ferti2 + ferti3
}

df = pd.DataFrame(data)

modelo = ols('rendimiento ~ C(fertilizante)', data=df).fit()

anova = sm.stats.anova_lm(modelo, typ = 2)

print(anova)   # P-valor = 0.00014, por lo que se rechaza HO. Por lo tanto, existe diferencia en el rendimiento del maíz entre los tres tipos de fertilizantes.

# Prueba de Turkey para saber si un fertilizante es mejor que otro:
tukey = pairwise_tukeyhsd(endog = df['rendimiento'], groups = df['fertilizante'], alpha = 0.1)

print(tukey)   

"""
CONCLUSIÓN:
La prueba ANOVA muestra que existe diferencia en el rendimiento del maíz entre los tres tipos de fertilizantes.
Por otro lado, la prueba Turkey muestra que los coeficientes de los p-valor evidencian que hay diferencias significativas para las tre combinaciones de fertilizantes analizadas. 
En contreto: Feri1 vs ferti2 = El fertilizante 2 muestra, en promedio, un mayor rendimiento. 
              Feri1 vs ferti3 = El fertilizante 3 muestra, en promedio, un mayor rendimiento. 
              Feri2 vs ferti3 = El fertilizante 3 muestra, en promedio, un mayor rendimiento.
Por lo tanto, los resultados muestran que el fertilizante 3 es el que presenta un mayor rendimiento del maíz.
# Out:
#                     sum_sq    df          F   PR(>F)
# C(fertilizante)  25.733333   2.0  20.315789  0.00014
# Residual          7.600000  12.0        NaN      NaN
# Multiple Comparison of Means - Tukey HSD, FWER=0.10
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
# ferti1 ferti2      1.8 0.0099 0.6597 2.9403   True
# ferti1 ferti3      3.2 0.0001 2.0597 4.3403   True
# ferti2 ferti3      1.4 0.0409 0.2597 2.5403   True
# --------------------------------------------------
